# %% [markdown]
# # Challenge 2: Count Commits
#
# Count how many commits were made in the past week.
#
# Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
#Your code
import json
import requests as req
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# False

# %%
github = os.getenv("token")

# %%
url='https://api.github.com/repos/dataptmad0124/lessons'

# %%
req.get(url)
# Out:
# <Response [200]>

# %%
# %pip install requests

# %%
res.json()
res.json().keys()
# Out:
# dict_keys(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'has_discussions', 'forks_count', 'mirror_url', 'archived', 'disabled', 'ope
# ...

# %%
# Example: print(variable[:10])

# %%
res.json()['commits_url']
# Out:
# 'https://api.github.com/repos/dataptmad0124/lessons/commits{/sha}'

# %%
#quito el sha. Lo puedo ejecutar así y me sale el primero 'sha': 'c2e6659b9d63408bbc3a93a71d02c1deecfb2f90; puedo poner ese código

url2='https://api.github.com/repos/dataptmad0124/lessons/commits'

# %%
req.get(url2).json()
# Out:
# [{'sha': 'c2e6659b9d63408bbc3a93a71d02c1deecfb2f90',
#   'node_id': 'C_kwDOLFIjbtoAKGMyZTY2NTliOWQ2MzQwOGJiYzNhOTNhNzFkMDJjMWRlZWNmYjJmOTA',
#   'commit': {'author': {'name': 'iudh',
#     'email': 'yeho@mail.com',
#     'date': '2024-02-10T10:24:17Z'},
#    'committer': {'name': 'iudh',
#     'email': 'yeho@mail.com',
#     'date': '2024-02-10T10:24:17Z'},
#    'message': 'web apis',
#    'tree': {'sha': '129437502600ce9d2572080b35dbbe4e77f8edb1',
#     'url': 'https://api.github.com/repos/dataptmad0124/lessons/git/trees/129437502600ce9d2572080b35dbbe4e77f8edb1'},
#    'url': 'https://api.github.com/repos/dataptmad0124/lessons/git/commits/c2e6659b9d63408bbc3a93a71d02c1deecfb2f90',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/dataptmad0124/lessons/commits/c2e6659b9d63408bbc3a93a71d02c1deecfb2f90',
# ...

# %%
len(req.get(url2).json())
# Out:
# 30
